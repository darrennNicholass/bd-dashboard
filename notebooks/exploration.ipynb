# %% [markdown]
# # Exploration — BD Analytics Dashboard
#
# Notebook untuk inspeksi struktur sumber data (Phase 2, 4, 6, 7).
#
# Aturan: hasil eksplorasi yang sudah stabil dipindahkan ke `src/`,
# notebook tidak menjadi tempat logika produksi.

# %%
import sys

sys.path.append("..")

from src import sheets

sheets.env_status()
